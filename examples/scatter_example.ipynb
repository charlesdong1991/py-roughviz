# %%
import sys
sys.path.append("..")

from roughviz.charts.scatter import Scatter

# %%
# Example 1

scatter = Scatter(data={"x": [1, 2, 35], "y": [10, 20, 8]})
scatter.show()
# Out:
# <html>
# <body>
#
# <div id=f68bf26c74584a8993a68db77cc87158></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.Scatter(
#   {"x": null, "y": null, "data": {"x": [1, 2, 35], "y": [10, 20, 8]}, "title": "", "width": 800, "height": 600, "interactive": true, "bowing": 0.2, "fillStyle": "cross-hatch", "fillWeight": 0, "strokeWidth": 1, "roughness": 1, "tooltipFontSize": "0.95rem", "titleFontSize": "0.95rem", "colors": ["coral", "skyblue", "#66c2a5", "tan", "#8da0cb", "#e78ac3", "#a6d854", "#ffd92f", "tan", "orange"], "margin": {"top": 50, "right": 20, "bottom": 70, "left": 100}, "xLabel": "", "yLabel": "", "axisFontSize": "1.5rem", "labelFontSize": "2rem", "colorZero": false, "font": "Gaegu", "radius": 8, "axisRoughness": 0.5, "highlight": "green", "innerStrokeWidth": 0, "simplification": 0.2, "stroke": "black", "element": "#f68bf26c74584a8993a68db77cc87158"}
# );
# 	var text = document.querySelectorAll(".xAxisf68bf26c74584a8993a68db77cc87158 .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("f68bf26c74584a8993a68db77cc87158").style.height = "px";
# 	document.querySelector("#f68bf26c74584a8993a68db77cc87158 svg").style.height = "px";
# });
# </script>
#
# </body>
# </html>

# %%
# Example 2

scatter = Scatter(data={"x": [1, 2, 35], "y": [10, 20, 8]})
scatter.set_title("Scatter Plot", fontsize=3)
scatter.set_xlabel("X", fontsize=2)
scatter.set_ylabel("Y", fontsize=2)

scatter.show()
# Out:
# <html>
# <body>
#
# <div id=f08872955be14059a2ce1adde632943d></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.Scatter(
#   {"x": null, "y": null, "data": {"x": [1, 2, 35], "y": [10, 20, 8]}, "title": "Scatter Plot", "width": 800, "height": 600, "interactive": true, "bowing": 0.2, "fillStyle": "cross-hatch", "fillWeight": 0, "strokeWidth": 1, "roughness": 1, "tooltipFontSize": "0.95rem", "titleFontSize": "3rem", "colors": ["coral", "skyblue", "#66c2a5", "tan", "#8da0cb", "#e78ac3", "#a6d854", "#ffd92f", "tan", "orange"], "margin": {"top": 50, "right": 20, "bottom": 70, "left": 100}, "xLabel": "X", "yLabel": "Y", "axisFontSize": "1.5rem", "labelFontSize": "2rem", "colorZero": false, "font": "Gaegu", "radius": 8, "axisRoughness": 0.5, "highlight": "green", "innerStrokeWidth": 0, "simplification": 0.2, "stroke": "black", "element": "#f08872955be14059a2ce1adde632943d"}
# );
# 	var text = document.querySelectorAll(".xAxisf08872955be14059a2ce1adde632943d .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("f08872955be14059a2ce1adde632943d").style.height = "px";
# 	document.querySelector("#f08872955be14059a2ce1adde632943d svg").style.height = "px";
# });
# </script>
#
# </body>
# </html>

# %%
# Example 3

scatter = Scatter(data="example_datasets/vis1.csv", x="a", y="b")
scatter.set_title("Scatter Plot", fontsize=3)
scatter.set_xlabel("X", fontsize=2)
scatter.set_ylabel("Y", fontsize=2)

scatter.show()
# Out:
# <html>
# <body>
#
# <div id=b9c0ec30a58b4015b4badcf1735eae5b></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.Scatter(
#   {"x": "a", "y": "b", "data": "example_datasets/vis1.csv", "title": "Scatter Plot", "width": 800, "height": 600, "interactive": true, "bowing": 0.2, "fillStyle": "cross-hatch", "fillWeight": 0, "strokeWidth": 1, "roughness": 1, "tooltipFontSize": "0.95rem", "titleFontSize": "3rem", "colors": ["coral", "skyblue", "#66c2a5", "tan", "#8da0cb", "#e78ac3", "#a6d854", "#ffd92f", "tan", "orange"], "margin": {"top": 50, "right": 20, "bottom": 70, "left": 100}, "xLabel": "X", "yLabel": "Y", "axisFontSize": "1.5rem", "labelFontSize": "2rem", "colorZero": false, "font": "Gaegu", "radius": 8, "axisRoughness": 0.5, "highlight": "green", "innerStrokeWidth": 0, "simplification": 0.2, "stroke": "black", "element": "#b9c0ec30a58b4015b4badcf1735eae5b"}
# );
# 	var text = document.querySelectorAll(".xAxisb9c0ec30a58b4015b4badcf1735eae5b .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("b9c0ec30a58b4015b4badcf1735eae5b").style.height = "px";
# 	document.querySelector("#b9c0ec30a58b4015b4badcf1735eae5b svg").style.height = "px";
# });
# </script>
#
# </body>
# </html>
